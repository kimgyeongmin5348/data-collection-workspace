# %% [markdown]
# [공공데이터포털서울특별시(소상공인시장진흥공단_상가)]
#
# https://www.data.go.kr/data/15083033/fileData.do

# %% [markdown]
# ### import

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
import platform

# %%
# OS에 따른 한글 폰트 설정
if platform.system() == 'Windows':
    plt.rc('font', family='Malgun Gothic')  # 윈도우: 맑은 고딕
elif platform.system() == 'Darwin':
    plt.rc('font', family='AppleGothic')    # 맥: 애플 고딕
else:
    plt.rc('font', family='NanumBarunGothic') # 리눅스

# 마이너스 기호 깨짐 방지
plt.rc('axes', unicode_minus=False)

# %%
filepath = './source/소상공인시장진흥공단_상가(상권)정보_서울_202603.csv'
df = pd.read_csv(filepath, sep=',' , encoding='utf-8')
df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9244\1745599745.py:2: DtypeWarning: Columns (0: 층정보) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filepath, sep=',' , encoding='utf-8')
#                  상가업소번호          상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA010120220800800619  참편한공인중개사사무소  NaN        L1      부동산      L102
# 1  MA010120220804265295      60계치킨암사  선사점        I2       음식      I210
# 2  MA010120220809658173       성심인력공사  NaN        N1  시설관리·임대      N104
# 3  MA010120220808205276          칸토빈  NaN        I2       음식      I212
# 4  MA010120220804370987      까치노래연습장  NaN        R1   예술·스포츠      R104
#
#   상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0  부동산 서비스    L10203  부동산 중개/대리업   L68221  ...  1165010100109270035014757
# 1    기타 간이    I21006          치킨   I56193  ...  1174010700105020004015779
# 2    고용 알선    N10401      고용 알선업   N75110  ...  1117010700100430059022991
# 3    비알코올     I21201          카페   I56221  ...  1150010800200200002002536
# 4   유원지·오락    R10407         노래방   R91223  ...  1135010500101690179002482
#
#        건물명                 도로명주소   구우편번호 신우편번호  동정보  층정보  호정보          경도  \
# 0      NaN   서울특별시 서초구 방배로19길 25  137843  6682  NaN    1  NaN  126.993691
# 1  암사동정웅빌딩     서울특별시 강동구 상암로3길 8  134877  5241  NaN    1  NaN  127.126859
# 2      NaN    서울특별시 용산구 한강대로 385  140821  4320  NaN  NaN  NaN  126.972240
# 3    공항시장역     서울특별시 강서구 방화동로 30  157240  7619  NaN    1  NaN  126.810493
# 4      NaN  서울특별시 노원구 한글비석로23길 2  139815  1682  NaN  NaN  NaN  127.071218
#
#           위도
# 0  37.484844
# 1  37.550810
# 2  37.552803
# 3  37.563548
# 4  37.660715
#
# [5 rows x 39 columns]

# %%
df.shape
# Out:
# (537489, 39)

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='str')

# %%
set(df['상권업종대분류명'])
# Out:
# {'과학·기술', '교육', '보건의료', '부동산', '소매', '수리·개인', '숙박', '시설관리·임대', '예술·스포츠', '음식'}

# %%
print(set(df['상권업종중분류명']))
# Out:
# {'기타 생활용품 소매', '중고 상품 소매', '교육 지원', '컴퓨터 수리', '식물 소매', '중식', '사무 지원', '광고', '서양식', '인쇄·제품제작', '기타 숙박', '산업용품 대여', '기타 상품 소매', '본사·경영 컨설팅', '비알코올 ', '장식품 소매', '장례식장 ', '기타 보건', '일반 교육', '세탁', '기타 외국', '법무관련 ', '회계·세무', '가정용품 대여', '시설관리', '안경·정밀기기 소매', '가전제품 수리', '담배 소매', '유원지·오락', '주점', '기술 서비스', '전문 디자인', '음료 소매', '기타 사업 서비스', '가전·통신 소매', '도서관·사적지', '기타 개인', '철물·건설자재 소매', '일식', '시장 조사', '연료 소매', '섬유·의복·신발 소매', '시계·귀금속 소매', '사진 촬영', '한식', '여행사·보조', '식료품 소매', '종합 소매', '욕탕·신체관리', '기타 간이', '기타 가정용품 수리', '병원', '자동차 부품 소매', '동남아시아', '조경·유지', '의약·화장품 소매', '가구 소매', '모터사이클 소매', '부동산 서비스', '고용 알선', '통신장비 수리', '애완동물·용품 소매', '운송장비 대여', '모터사이클 수리', '의원', '이용·미용', '구내식당·뷔페', '청소·방제', '스포츠 서비스', '기타 전문 과학', '수의', '일반 숙박', '기타 교육', '자동차 수리·세차', '오락용품 소매'}

# %%
# 결측치
df.isnull().sum()
# Out:
# 상가업소번호            0
# 상호명               0
# 지점명          490488
# 상권업종대분류코드         0
# 상권업종대분류명          0
# 상권업종중분류코드         0
# 상권업종중분류명          0
# 상권업종소분류코드         0
# 상권업종소분류명          0
# 표준산업분류코드        198
# 표준산업분류명         198
# 시도코드              0
# 시도명               0
# 시군구코드             0
# 시군구명              0
# 행정동코드             0
# 행정동명              0
# 법정동코드             0
# 법정동명              0
# 지번코드              0
# 대지구분코드            0
# 대지구분명             0
# 지번본번지            24
# 지번부번지         94482
# 지번주소              0
# 도로명코드             0
# 도로명               0
# 건물본번지             2
# 건물부번지        467846
# 건물관리번호         2272
# 건물명          286831
# 도로명주소             0
# 구우편번호             0
# 신우편번호             0
# 동정보          537489
# 층정보          200654
# 호정보          537489
# 경도                0
# 위도                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='str')

# %%
# 시도명에서 '서울특별시' 만 존재한다.
df['시도명'].unique()
# Out:
# <StringArray>
# ['서울특별시']
# Length: 1, dtype: str

# %%
# missingno 실행시 오류가 발생하면 설치한다.
#!pip install missingno

# %%
# 결측시를 시각화해서 볼 수 있다.
import missingno as msno

# %%
# plt.rc('font', family='NanumBarunGothic')

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
df['상권업종대분류명'].value_counts()
# Out:
# 상권업종대분류명
# 음식         138558
# 소매         112810
# 과학·기술       92306
# 수리·개인       52039
# 교육          45080
# 부동산         24475
# 시설관리·임대     23812
# 예술·스포츠      20739
# 보건의료        18999
# 숙박           8671
# Name: count, dtype: int64

# %%
df['상권업종중분류명'].value_counts()
# Out:
# 상권업종중분류명
# 한식             53225
# 이용·미용          30997
# 섬유·의복·신발 소매    26895
# 기타 간이          26558
# 부동산 서비스        24475
#                ...
# 장례식장             478
# 모터사이클 소매         413
# 통신장비 수리          312
# 조경·유지            120
# 기타 외국             35
# Name: count, Length: 75, dtype: int64

# %%
sns.countplot(data=df, y='상권업종대분류명')
# Out:
# <Axes: xlabel='count', ylabel='상권업종대분류명'>

# %%
# df['상권업종대분류명']=='음식'    VS  df['상권업종대분류명'].str.contains('음식')  서로 같다
#df[df['상권업종대분류명']=='음식']

df_food = df.loc[df['상권업종대분류명'].str.contains('음식')]
df_food.shape
# Out:
# (138558, 39)

# %%
df_food.head()
# Out:
#                   상가업소번호      상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명  \
# 1   MA010120220804265295  60계치킨암사  선사점        I2       음식      I210    기타 간이
# 3   MA010120220808205276      칸토빈  NaN        I2       음식      I212    비알코올
# 9   MA010120220809640417    솜노래팡팡  NaN        I2       음식      I211       주점
# 25  MA010120220812811919  읏듬돈생삼겹살  NaN        I2       음식      I201       한식
# 35  MA010120220806699845   유명숯불갈비  NaN        I2       음식      I201       한식
#
#    상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...                     건물관리번호      건물명  \
# 1     I21006         치킨   I56193  ...  1174010700105020004015779  암사동정웅빌딩
# 3     I21201         카페   I56221  ...  1150010800200200002002536    공항시장역
# 9     I21104      요리 주점   I56219  ...  1165010800115770002022148      NaN
# 25    I20107  돼지고기 구이/찜   I56113  ...  1129013900103840023002884      NaN
# 35    I20107  돼지고기 구이/찜   I56113  ...  1150010300108390011020946      NaN
#
#                    도로명주소   구우편번호 신우편번호  동정보 층정보  호정보          경도         위도
# 1      서울특별시 강동구 상암로3길 8  134877  5241  NaN   1  NaN  127.126859  37.550810
# 3      서울특별시 강서구 방화동로 30  157240  7619  NaN   1  NaN  126.810493  37.563548
# 9   서울특별시 서초구 서초대로50길 75  137875  6650  NaN   1  NaN  127.013852  37.489862
# 25   서울특별시 성북구 화랑로40길 43  136817  2781  NaN   1  NaN  127.064015  37.613579
# 35    서울특별시 강서구 곰달래로 233  157902  7738  NaN   2  NaN  126.858861  37.531981
#
# [5 rows x 39 columns]

# %%
df_food['상권업종대분류명'].unique()
# Out:
# <StringArray>
# ['음식']
# Length: 1, dtype: str

# %%
sns.countplot(data=df_food, y='상권업종중분류명')
# Out:
# <Axes: xlabel='count', ylabel='상권업종중분류명'>

# %% [markdown]
# ### 이디야와 할리스

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='str')

# %%
dataset = df[['상호명', '지점명', '상권업종중분류명', '시도명', '시군구명', '행정동명', '도로명', '경도', '위도']]
dataset.head()

#print(dataset['상권업종중분류명'].unique())

# '비알코올' 뒤에 공백이 있으므로 주의하세요
df_coffee = dataset[dataset['상권업종중분류명']=='비알코올 ']
df_coffee.head()
# Out:
#          상호명  지점명 상권업종중분류명    시도명  시군구명 행정동명                 도로명          경도  \
# 3        칸토빈  NaN    비알코올   서울특별시   강서구  공항동      서울특별시 강서구 방화동로  126.810493
# 51   빽다방구산역점  NaN    비알코올   서울특별시   은평구  구산동       서울특별시 은평구 연서로  126.916688
# 78      맹커피숍  NaN    비알코올   서울특별시   은평구  대조동       서울특별시 은평구 불광로  126.928818
# 109       담다  NaN    비알코올   서울특별시  동대문구  용두동  서울특별시 동대문구 왕산로19가길  127.031631
# 118       초원  NaN    비알코올   서울특별시  동대문구  신설동      서울특별시 동대문구 왕산로  127.024498
#
#             위도
# 3    37.563548
# 51   37.610477
# 78   37.610773
# 109  37.581067
# 118  37.576284

# %%
df_coffee['상권업종중분류명'].unique()
# Out:
# <StringArray>
# ['비알코올 ']
# Length: 1, dtype: str

# %%
print(df_coffee['상호명'])
# Out:
# 3                    칸토빈
# 51               빽다방구산역점
# 78                  맹커피숍
# 109                   담다
# 118                   초원
#                ...
# 537363    스페이스맘(서원안길 합정)
# 537395        커피앳웍스 센터원점
# 537425      메이 베이크 커피베이킹
# 537437     메가엠지씨커피 논현동현점
# 537476       텐퍼센트커피 창동역점
# Name: 상호명, Length: 21619, dtype: str

# %%
df_coffee['상호명'].value_counts()
# Out:
# 상호명
# 투썸플레이스            70
# 메가엠지씨커피           63
# 이디야커피             57
# 이디야               57
# 컴포즈커피             43
#                   ..
# 스페이스맘(서원안길 합정)     1
# 커피앳웍스 센터원점         1
# 메이 베이크 커피베이킹       1
# 메가엠지씨커피 논현동현점      1
# 텐퍼센트커피 창동역점        1
# Name: count, Length: 19074, dtype: int64

# %%
# %%
df_coffee[df_coffee['상호명'].str.contains('이디야|ediya|EDIYA')].shape
# Out:
# (436, 9)

# %%
df_coffee[df_coffee['상호명'].str.contains('할리스|hollys|HOLLYS')].shape
# Out:
# (114, 9)

# %%
df_coffee.loc[df_coffee['상호명'].str.contains('이디야|ediya|EDIYA'),'상호명'].unique()
# Out:
# <StringArray>
# [        '이디야커피',        '이디야성산점',        '이디야강서점',           '이디야',
#         '이디야커피숍',        '이디야포이점',    '이디야연신내통일로점',         '이디야삼성',
#           '이디야주',     '이디야커피길동역점',
#  ...
#  '이디야 왕십리비트플렉스점',       '이디야 갈현점',     '이디야 자양문원점',      '이디야용산원효점',
#     '이디야커피 먹골역점',      '이디야청량리역점',    '이디야커피르피에드점',       '이디야대방역점',
#        '이디야상계동점',   '이디야커피 염창대로점']
# Length: 315, dtype: str

# %%
df_coffee.loc[df_coffee['상호명'].str.contains('할리스|hollys|HOLLYS'),'상호명'].unique()
# Out:
# <StringArray>
# [         '할리스커피이수역점',            '할리스신림역점',           '할리스커피수서점',
#         '할리스가산디지털단지점',          '할리스커피홍대역점', '모닝에프디(할리스커피노량진역점)주',
#         '할리스커피테크노마트점',       '할리스커피구로거리공원점',         '할리스커피홍대역2번',
#             '할리스커피남부',                '할리스',         '할리스고덕리엔파크점',
#           '할리스청담삼성로점',              '할리스커피',            '할리스커피난곡',
#       '할리스커피백석예술대학교점',        '할리스커피강남대로논현',         '할리스커피충정래미안',
#     '할리스커피구로디지털뉴스테이점',        '할리스커피굽은다리역점',     '할리스커피선유도역점TS카페',
#             '할리스대방역점',           '할리스샹제리제점',             '할리스도심2',
#          '할리스커피수락산역점',     '서울고무상사할리스종로5가점',          '할리스커피구로역점',
#           '할리스고덕그라시움',           '할리스독립문역점',         '케이지할리스에프앤비',
#             '할리스커피도심',            '할리스개화산점',          '할리스엘지리테일주',
#               '할리스시흥',              '할리스숙대',            '할리스노원역점',
#            '할리스가산대륭2',            '할리스강변역점',            '할리스등촌역점',
#           '할리스서서울공원점',           '할리스메리츠봉래',          '할리스여의도포스트',
#            '할리스오목교역점',              '할리스2점',          '할리스북한산DI점',
#             '할리스커피배명',           '할리스커피한양대',             '할리스커피세',
#             '할리스커피홍대',      '할리스커피클럽역삼테헤란점',           '할리스커피신사역',
#          '할리스커피구반포역점',         '할리스커피낙성대역점',          '할리스커피대림역점',
#             '할리스명동역점',     '할리스커피종로코리안리빌딩점',        '할리스커피홍대입구역점',
#        '할리스커피용산더프라임점',          '할리스연트럴파크점',            '할리스청계천점',
#         '할리스커피신촌연세로점',       '할리스커피건대일감호수점',        '할리스커피센터포인트점',
#         '할리스길동포유르센티점',         '할리스커피광나루역점',        '할리스커피한남순천향점',
#             '할리스커피종로',      '할리스커피공덕경의선숲길점',            '할리스충무로점',
#         '할리스커피전경련회관점',            '할리스종각역점',            '할리스덕수궁점',
#        '할리스커피여의도파이낸스',            '할리스신촌역점',         '할리스에프앤비신채널',
#            '할리스이태원역점',           '할리스충정로역점',               '할리스점',
#           '할리스 충정로역점',        '할리스커피종로DGB점',           '할리스커피보라매',
#        '할리스커피잠실광고회관점',            '할리스커피대명',          '할리스커피고대안암',
#           '할리스커피클럽역삼',     '할리스커피구로디지털단지역점',         '할리스커피서울대예술',
#            '할리스커피서울대',         '할리스커피세로수길점',          '할리스커피구산역점',
#            '할리스커피을지로',      '할리스커피여의도하나투자점',      '할리스커피삼성금융캠퍼스점',
#            '할리스FKI타워']
# Length: 94, dtype: str

# %%
# 이디야와 할리스 데이터 가져오기
df_coffee_edi_holly =  df_coffee.loc[df_coffee['상호명'].str.contains('이디야|ediya|EDIYA|할리스|hollys|HOLLYS')].copy()
df_coffee_edi_holly.shape
# Out:
# (550, 9)

# %%
df_coffee_edi_holly.sample(5)
# Out:
#              상호명    지점명 상권업종중분류명    시도명 시군구명         행정동명                도로명  \
# 199823       이디야  동대문역점    비알코올   서울특별시  종로구      종로5.6가동      서울특별시 종로구 율곡로
# 387422   이디야커피중계     본점    비알코올   서울특별시  노원구         중계본동  서울특별시 노원구 중계로14바길
# 216527  이디야탑골공원점    NaN    비알코올   서울특별시  종로구  종로1.2.3.4가동      서울특별시 종로구 수표로
# 18311    할리스신림역점    NaN    비알코올   서울특별시  관악구          서원동      서울특별시 관악구 신림로
# 486340  할리스커피한양대    병원점    비알코올   서울특별시  성동구          사근동     서울특별시 성동구 왕십리로
#
#                 경도         위도
# 199823  127.008048  37.571853
# 387422  127.082574  37.649877
# 216527  126.989201  37.571015
# 18311   126.929686  37.482237
# 486340  127.045633  37.558636

# %%
# 상호명에 이디야가 포함된 것에 브랜드명 컬럼명을 추가하고 '이디야'을 저장한다.
df_coffee_edi_holly.loc[df_coffee_edi_holly['상호명'].str.contains('이디야|ediya|EDIYA'),'브랜드명'] ='이디야'

# %%
# 상호명에 이디야가 포함된 것에 브랜드명 컬럼명을 추가하고 '할리스'을 저장한다.
df_coffee_edi_holly.loc[df_coffee_edi_holly['상호명'].str.contains('할리스|hollys|HOLLYS'),'브랜드명'] ='할리스'

# %%
df_coffee_edi_holly.sample(5)
# Out:
#                      상호명   지점명 상권업종중분류명    시도명  시군구명  행정동명             도로명  \
# 413961  비지에프휴먼넷이디야관악산으뜸점   NaN    비알코올   서울특별시   관악구   대학동   서울특별시 관악구 신림로
# 252790           이디야라이프점   NaN    비알코올   서울특별시  영등포구   여의동  서울특별시 영등포구 63로
# 520225          할리스커피을지로   입구점    비알코올   서울특별시    중구    명동   서울특별시 중구 명동3길
# 519485             할리스커피  합정역점    비알코올   서울특별시   마포구   합정동   서울특별시 마포구 양화로
# 170070               이디야   NaN    비알코올   서울특별시   성동구  행당1동  서울특별시 성동구 왕십리로
#
#                 경도         위도 브랜드명
# 413961  126.945367  37.468307  이디야
# 252790  126.939210  37.519553  이디야
# 520225  126.983418  37.564762  할리스
# 519485  126.913340  37.548513  할리스
# 170070  127.034622  37.561208  이디야

# %%
df_coffee_edi_holly['브랜드명'].unique()
# Out:
# <StringArray>
# ['이디야', '할리스']
# Length: 2, dtype: str

# %%
df_coffee_edi_holly['브랜드명'].value_counts()
# Out:
# 브랜드명
# 이디야    436
# 할리스    114
# Name: count, dtype: int64

# %%
geo_df_coffee =  df_coffee_edi_holly.copy()

# %%
#!pip install folium

# %%
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 import folium
#
# ModuleNotFoundError: No module named 'folium'

# %%
folium.Map
# Out:
# folium.folium.Map

# %%
map = folium.Map(location=[geo_df_coffee['위도'].mean(), geo_df_coffee['경도'].mean()],
           zoom_start=12, tiles='OpenStreetMap')  # tiles='OpenStreetMap'


for n in geo_df_coffee.index:
  #팝업에 들어갈 텍스트를 지정해 준다.
  popup_name=geo_df_coffee.loc[n,'상호명'] + ' - '\
  +geo_df_coffee.loc[n, '도로명']

  if geo_df_coffee.loc[n,'브랜드명']=='이디야':
    icon_color='blue'
  else:
    icon_color='red'

  folium.CircleMarker(
      location=[geo_df_coffee.loc[n, '위도'],geo_df_coffee.loc[n,'경도']],
      radius = 3,
      popup =popup_name,
      color = icon_color,
      fill=True,
      fill_color=icon_color
  ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ef4895b6aaf6aa3abb43c215c4e625f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ef4895b6aaf6aa3abb43c215c4e625f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ef4895b6aaf6aa3abb43c215c4e625f = L.map(
#                 &quot;map_3ef4895b6aaf6aa3abb43c215c4e625f&quot;,
#                 {
#                     center: [35.181097, 129.069354],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d78fee2cfe6a9727fe231717258745e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d78fee2cfe6a9727fe231717258745e7.addTo(map_3ef4895b6aaf6aa3abb43c215c4e625f);
#
#
#             var circle_marker_1f00e6321657d4e66a76a5724132d6ca = L.circleMarker(
#                 [37.5820889406996, 127.003181304281],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3ef4895b6aaf6aa3abb43c215c4e625f);
#
#
#         var popup_ea028216dca7413ebb237c592f5735d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9be504f0c8392787f14d2d4599159e3b = $(`&lt;div id=&quot;html_9be504f0c8392787f14d2d4599159e3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;이디야커피 - 서울특별시 종로구 대학로10길&lt;/div&gt;`)[0];
#                 popup_ea028216dca7413ebb237c592f5735d4.setContent(html_9be504f0c8392787f14d2d4599159e3b);
#
#
#
#         circle_marker_1f00e6321657d4e66a76a5724132d6ca.bindPopup(popup_ea028216dca7413ebb237c592f5735d4)
#         ;
#
#
#
#
#             var circle_marker_b9973a9c51f0d391144fab2d2ae9a98f = L.circleMarker(
#                 [37.6012450035223, 126.956322292776],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3ef4895b6aaf6aa3abb43c215c4e625f);
#
#
#         var popup_3fa1cf90dde6f3e3ac29ee10aed6083f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fe821ec6f08a089760a54d6419459da = $(`&lt;div id=&quot;html_6fe821ec6f08a089760a54d6419459da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;이디야커피 - 서울특별시 종로구 홍지문2길&lt;/div&gt;`)[0];
#                 popup_3fa1cf90dde6f3e3ac29ee10aed6083f.setContent(html_6fe821ec6f08a089760a54d6419459da);
#
#
#
#         circle_marker_b9973a9c51f0d391144fab2d2ae9a98f.bindPopup(popup_3fa1cf90dde6f3e3ac29ee10aed6083f)
#         ;
#
#
#
#
#             var circle_marker_b38d968a9c720b8d834a9a256f07ee42 = L.circleMarker(
#                 [37.5700964433243, 126.991532975056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3ef4895b6aaf6aa3abb43c215c4e625f);
#
#
#         var popup_a130ffd5e342f55635464cc2ed72779d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c04dd292cb9c2adebb248eb787bb0fdb = $(`&lt;div id=&quot;html_c04dd292cb9c2adebb248eb787bb0fdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;이디야커피 - 서울특별시 종로구 종로&lt;/div&gt;`)[0];
#                 popup_a130ffd5e342f55635464cc2ed72779d.setContent(html_c04dd292cb9c2adebb248eb787bb0fdb);
#
#
#
#         circle_marker_b38d968a9c720b8d834a9a256f07ee42.bindPopup(popup_a130ffd5e342f55635464cc2ed72779d)
#         ;
